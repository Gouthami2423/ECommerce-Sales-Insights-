# %%
import pandas as pd

df = pd.read_csv("sales_data.csv")

df.head()
# Out:
#    order_id customer_id product_id  order_date product_category  quantity  \
# 0         1     CUST291     PROD29  2025-03-02            Books         2
# 1         2     CUST797     PROD65  2025-05-08         Clothing         4
# 2         3     CUST353     PROD61  2025-07-16            Books         2
# 3         4     CUST993     PROD47  2025-03-27      Electronics         5
# 4         5     CUST258     PROD35  2025-01-25      Electronics         3
#
#    unit_price  total_price
# 0        4134         8268
# 1        3502        14008
# 2        1858         3716
# 3        3735        18675
# 4        4622        13866

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          1000 non-null   int64
#  1   customer_id       1000 non-null   object
#  2   product_id        1000 non-null   object
#  3   order_date        1000 non-null   object
#  4   product_category  1000 non-null   object
#  5   quantity          1000 non-null   int64
#  6   unit_price        1000 non-null   int64
#  7   total_price       1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# order_id            0
# customer_id         0
# product_id          0
# order_date          0
# product_category    0
# quantity            0
# unit_price          0
# total_price         0
# dtype: int64

# %%
df.describe()
# Out:
#           order_id     quantity   unit_price   total_price
# count  1000.000000  1000.000000  1000.000000   1000.000000
# mean    500.500000     2.961000  2658.303000   7903.296000
# std     288.819436     1.442761  1397.627641   6024.051116
# min       1.000000     1.000000   206.000000    242.000000
# 25%     250.750000     2.000000  1421.750000   3026.500000
# 50%     500.500000     3.000000  2662.000000   6107.500000
# 75%     750.250000     4.000000  3882.000000  11620.500000
# max    1000.000000     5.000000  4999.000000  24895.000000

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['product_category'] = df['product_category'].str.title()

# %%
df = df.drop_duplicates()

# %%
import matplotlib.pyplot as plt
monthly_sales = df.groupby(df['order_date'].dt.month)['total_price'].sum()

monthly_sales.plot(kind='line')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()


category_sales = df.groupby('product_category')['total_price'].sum()

category_sales.plot(kind='bar')
plt.title("Sales by Product Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()


unique_customers = df['customer_id'].nunique()
unique_customers
# Out:
# 597

# %%
total_sales = df['total_price'].sum()
total_sales
# Out:
# np.int64(7903296)

# %%
total_orders = df['order_id'].nunique()
total_orders
# Out:
# 1000

# %%
average_order_value = total_sales / total_orders
average_order_value
# Out:
# np.float64(7903.296)

# %%
monthly_sales
# Out:
# order_date
# 1     605114
# 2     638953
# 3     701286
# 4     610832
# 5     624934
# 6     633327
# 7     675837
# 8     744098
# 9     723849
# 10    779413
# 11    608695
# 12    556958
# Name: total_price, dtype: int64
